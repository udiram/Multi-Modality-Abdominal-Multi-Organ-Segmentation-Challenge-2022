# %%
# !pip install monailabel
# Out:
# ...
#   Using cached monailabel-0.4.1-202207060352-py3-none-any.whl (5.9 MB)
# ...
#   Using cached numpymaxflow-0.0.2-cp39-cp39-win_amd64.whl (22 kB)
# ...
#   Using cached httpx-0.23.0-py3-none-any.whl (84 kB)
# ...
#   Using cached ninja-1.10.2.3-py2.py3-none-win_amd64.whl (292 kB)
# ...
#   Using cached fastapi-0.78.0-py3-none-any.whl (54 kB)
# ...
#   Using cached python_multipart-0.0.5-py3-none-any.whl
# ...
#   Using cached watchdog-2.1.8-py3-none-win_amd64.whl (77 kB)
# ...
#   Using cached schedule-1.1.0-py2.py3-none-any.whl (10 kB)
# ...
#   Using cached pydantic-1.9.1-cp39-cp39-win_amd64.whl (2.0 MB)
# ...
#   Using cached uvicorn-0.17.6-py3-none-any.whl (53 kB)
# ...
#   Using cached expiringdict-1.2.1-py3-none-any.whl
# ...
#   Using cached requests_toolbelt-0.9.1-py2.py3-none-any.whl (54 kB)
# ...
#   Using cached timeloop-1.0.2-py3-none-any.whl
# ...
#   Using cached girder_client-3.1.14-py3-none-any.whl
# ...
#   Using cached python_dotenv-0.20.0-py3-none-any.whl (17 kB)
# ...
#   Using cached pydicom_seg-0.4.0-py3-none-any.whl (25 kB)
# ...
